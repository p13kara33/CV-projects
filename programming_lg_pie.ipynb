# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mydict = {"Python":{"Total":0.4, "Excel":0.2, "Tkinter":0.1, "Statistics":0.35,"Machine Learning":0.35}, 
          "WebDev":{"Total":0.2, "JS":0.3, "HTML":0.35, "CSS":0.35},
        "DB":{"Total":0.2, "Mysql":30, "psql":40, "MongoDB":30},
         "Microsoft Excel": {"Total":.15},
         "Tableau":{"Total":5},
         "Unity":{"Total":.025},
         "3Ds Max":{"Total":0.025}}
df = pd.DataFrame(data=mydict)
df = df.fillna(0)
df
# Out:
#                   Python  WebDev    DB  Microsoft Excel  Tableau  Unity  \
# Total               0.40    0.20   0.2             0.15      5.0  0.025
# Excel               0.20    0.00   0.0             0.00      0.0  0.000
# Tkinter             0.10    0.00   0.0             0.00      0.0  0.000
# Statistics          0.35    0.00   0.0             0.00      0.0  0.000
# Machine Learning    0.35    0.00   0.0             0.00      0.0  0.000
# JS                  0.00    0.30   0.0             0.00      0.0  0.000
# HTML                0.00    0.35   0.0             0.00      0.0  0.000
# CSS                 0.00    0.35   0.0             0.00      0.0  0.000
# Mysql               0.00    0.00  30.0             0.00      0.0  0.000
# psql                0.00    0.00  40.0             0.00      0.0  0.000
# MongoDB             0.00    0.00  30.0             0.00      0.0  0.000
#
#                   3Ds Max
# Total               0.025
# Excel               0.000
# ...

# %%
# plt.figure(figsize=(10,10))
# sns.set_style('whitegrid')

# ax = sns.barplot(x='Tools', y="Percentages", data=df)

# %%
plt.figure(figsize=(10,10))

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ["Python", 'WebDev', "DB", "Microsoft Excel", "Tableau", "Unity"]
sizes = [40, 20, 15, 15, 5, 5]
explode = (0, 0, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')


plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, textprops={'fontsize': 14, 'family':'Verdana'})
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-419dd472e689> in <module>
#       7
#       8
# ----> 9 plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#      10         shadow=True, startangle=90, textprops={'fontsize': 14, 'family':'Verdana', "style":"strong"})
#      11 plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2746         wedgeprops=None, textprops=None, center=(0, 0), frame=False,
#    2747         rotatelabels=False, *, data=None):
# -> 2748     return gca().pie(
#    2749         x, explode=explode, labels=labels, colors=colors,
# ...
